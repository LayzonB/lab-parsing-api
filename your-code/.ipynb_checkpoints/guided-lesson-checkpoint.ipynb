# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
#from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %%
response = requests.get(url)
response.text
# Out:
# '<!DOCTYPE html>\n<html>\n  <head>\n    <link\n      rel="shortcut icon"\n      href="data:image/png;base64,..."\n    />\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <title>ZALANDO</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style>\n      html,\n      body {\n        padding: 0;\n        margin: 0;\n        height: 100%;\n      }\n      header {\n        height: 90px;\n        display: block;\n        text-align: center;\n      }\n      header svg {\n        padding-top: 30px;\n      }\n      .reference {\n        color: #ff6900;\n        font-size: 12px;\n        font-weight: bold;\n      }\n      .z-500-error-page {\n        display: flex;\n        align-items: center;\n        justify-content: center;\n        font-family: ArialMT, Arial, Helvetica, sans-serif;\n        color: #1a1a1a;\n        background-color: #f7f7f7;\n        min-height: 600px;\n        height: calc(100% - 92px);\n      }\n      main {\n        padding-top: 40px;\n        text-align: center;\n      }\n      .z-500-error-page svg {\n        margin: 0 auto 39px;\n      }\n      .z-500-error-page h1 {\n        margin: 0 auto;\n        margin-bottom: 20px;\n        font-size: 34px;\n        width: 60%;\n      }\n      .z-500-error-page p {\n        font-size: 16px;\n        margin: 0 auto 37px;\n        line-height: 1.5;\n        letter-spacing: 0.7px;\n        max-width: 660px;\n      }\n      .z-500-error-page a {\n        margin: 0 9px;\n        padding: 15px 50px;\n        display: inline-block;\n        color: white;\n        background: black;\n        font-size: 14px;\n        font-weight: 700;\n        text-align: center;\n        text-decoration: none;\n        letter-spacing: 0.5px;\n        cursor: pointer;\n        border: 2px solid #000;\n        position: relative;\n        min-width: 135px;\n        box-sizing: border-box;\n        border-radius: 5px;\n      }\n      .z-500-error-page a:before {\n        content: "";\n        position: absolute;\n        top: 0;\n        bottom: 0;\n        left: 0;\n        width: 0;\n        background-color: #000;\n        -o-transition: width 0.3s ease 0s;\n        -moz-transition: width 0.3s ease 0s;\n        -webkit-transition: width 0.3s ease 0s;\n        transition: width 0.3s ease 0s;\n        z-index: -1;\n      }\n      .z-500-error-page a:hover {\n        -o-transition: color 0.3s ease 0s;\n        -moz-transition: color 0.3s ease 0s;\n        -webkit-transition: color 0.3s ease 0s;\n        transition: color 0.3s ease 0s;\n      }\n      .z-500-error-page a:hover:before {\n        width: 100%;\n      }\n      @media screen and (max-width: 599px) {\n        .z-500-error-page {\n          padding: 30px 20px 50px;\n        }\n        .z-500-error-page h1 {\n          font-size: 24px;\n        }\n        .z-500-error-page a {\n          display: block;\n          margin: 28px auto;\n          width: 80%;\n        }\n      }\n      .z-500-error-page [lang] {\n        display: none;\n      }\n    </style>\n  </head>\n  <body>\n    <header>\n      <svg width="160" viewBox="0 0 99 20" xmlns="http://www.w3.org/2000/svg">\n        <title>zalando_logo_20</title>\n        <g fill="none" fill-rule="evenodd">\n          <path\n            d="M43.21 4.944c-.715-.398-1.777-.593-3.248-.593-2.012.002-3.88.426-4.586.693-.16.052-.33.192-.334.43v.054l.2 1.016.004.02c.062.205.232.3.385.3h.003c.05-.004.088-.014.124-.023l.335-.08c.877-.22 2.202-.558 3.68-.558.898 0 1.5.08 1.905.252.656.253.66.684.667 1.397v1.067c-.075-.002-.202-.003-.397-.003-.725 0-2.15.035-3.55.262-2.138.334-3.907.853-3.895 3.845 0 3.798 3.47 3.804 5.136 3.808 1.13-.002 2.175-.172 2.858-.314 1.555-.367 1.953-.868 1.932-2.437V7.763c0-.964.004-2.162-1.22-2.82zm-.855 9.753c-.828.273-1.734.41-2.694.41v.09-.09c-1.534-.012-3.03-.19-3.033-2.175.01-1.58.84-1.767 1.89-2.005l.073-.017c.934-.203 3.282-.24 3.765-.246v4.033zm19.41-6.935v6.314c.02 1.57-.377 2.07-1.933 2 ...

# %%
import urllib.request


data = urllib.request.urlopen(url).read().decode()
obj = json.loads(data)

# %%
flattened_data = pd.json_normalize(obj)

flattened_data1 = pd.json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   NE214D062-K11                              Baskets basses - navy
# 1   PE623G02E-J11    2 PACK - T-shirt à manches longues - pink/white
# 2   AD126K01Z-G11               Veste de survêtement - scarlet/white
# 3   SO223L096-Q11                              Veste d'hiver - black
# 4   N1243A0Z9-Q11  PICO 5 UNISEX - Chaussures d'entraînement et d...
# ..            ...                                                ...
# 79  VA216D03E-K11  OLD SKOOL EXCLUSIVE - Baskets basses - multico...
# 80  NI114D0GD-Q11            VALIANT  - Baskets basses - black/white
# 81  NI114D0F1-Q13  AIR MAX FUSION UNISEX - Baskets basses - black...
# 82  GU123G05X-A11             T-shirt à manches longues - true white
# 83  AS143A05P-Q14  JOLT 2 - Chaussures de running neutres - black...
#
#                                                 sizes  \
# 0   [28, 29, 30, 31, 32, 33, 34.5, 35, 36, 37, 38,...
# 1                      [3a, 4a, 5a, 6a, 8a, 10a, 12a]
# 2   [7-8a, 8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13...
# 3                                [10a, 12a, 14a, 16a]
# 4          [17, 18.5, 19.5, 21, 22, 23.5, 25, 26, 27]
# ..                                                ...
# 79                   [27, 28, 29, 30, 31, 32, 33, 34]
# 80  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
# 81  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# 82                       [7a, 8a, 10a, 12a, 14a, 16a]
# 83                   [35.5, 36, 37, 38, 39, 39.5, 40]
#
#                                               url_key  \
# 0   new-balance-yv373eno-baskets-basses-navy-ne214...
# 1   petit-bateau-2-pack-t-shirt-a-manches-longues-...
# 2   adidas-originals-veste-en-sweat-zippee-scarlet...
# 3            soliver-veste-dhiver-black-so223l096-q11
# 4   nike-performance-pico-5-chaussures-dentraineme...
# ..                                                ...
# 79  vans-old-skool-exclusive-baskets-basses-multic...
# 80  nike-sportswear-md-valiant-baskets-basses-blac...
# 81  nike-sportswear-air-max-fusion-baskets-basses-...
# 82  guess-core-t-shirt-a-manches-longues-true-whit...
# 83  asics-jolt-2-chaussures-de-running-neutres-as1...
#
#                                                 media        brand_name  \
# 0   [{'path': 'spp-media-p1/0a62f7e79322345d914c33...       New Balance
# 1   [{'path': 'spp-media-p1/429b9e4451c43e609230a1...      Petit Bateau
# 2   [{'path': 'spp-media-p1/98cb8c936eaf34e0972e01...  adidas Originals
# 3   [{'path': 'spp-media-p1/e36769e4fdb435318ee8e3...          s.Oliver
# 4   [{'path': 'spp-media-p1/a25d55434efd36fd802c2f...  Nike Performance
# ..                                                ...               ...
# 79  [{'path': 'spp-media-p1/41b60bb58bb63c7a981b8b...              Vans
# 80  [{'path': 'spp-media-p1/9f5ae0ae42e13659be6524...   Nike Sportswear
# 81  [{'path': 'spp-media-p1/0ed12842557638d1b2a431...   Nike Sportswear
# 82  [{'path': 'spp-media-p1/e8aeb3618a823e5d97e52e...             Guess
# 83  [{'path': 'spp-media-p1/f43f9ee616803faeaf22b2...             ASICS
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing
# 3   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-40%', 'tra...          shoe
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -15...          shoe
# 81  [{'key': 'discountRate', 'value': 'Jusqu’à -10...          shoe
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        54,95 €           49,45 €
# 1                 []        19,95 €           15,95 €
# 2                 []        38,95 €           27,25 €
# 3                 []        59,99 €           50,99 €
# 4                 []        25,95 €           19,45 €
# ..               ...            ...               ...
# 79                []        49,95 €           29,95 €
# 80                []        38,95 €           33,05 €
# 81                []        59,95 €           53,95 €
# 82                []        18,95 €           15,25 €
# 83                []        38,95 €           31,15 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                        True                                False
# 81                        True                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                    True
# 81                                    True
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount
# 0                                       False    NaN
# 1                                       False    NaN
# 2                                       False    NaN
# 3                                       False    NaN
# 4                                       False    NaN
# ..                                        ...    ...
# 79                                      False    NaN
# 80                                      False    NaN
# 81                                      False    NaN
# 82                                      False    NaN
# 83                                      False  194 g
#
# [84 rows x 18 columns]

# %%
total_pages=obj['pagination']['page_count']
total_pages
# Out:
# 276

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
#total_pages= obj['pagination']['page_count']
total_pages=4
# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url)
    data = urllib.request.urlopen(url).read().decode()
    obj = json.loads(data)    
    flattened_data = pd.json_normalize(obj)
    flattened_data1 = pd.json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
#                                                             name  \
# sku
# NI114D0CS-Q12            COURT BOROUGH  - Baskets basses - black
# C1853E00F-Q11                LOGO BELT UNISEX - Ceinture - black
# LE224A08D-Q11       LVB 512 SLIM TAPER JEANS - Jean slim - hydra
# LE226G005-A11              BATWING TEE - T-shirt imprimé - white
# EL943D006-K11    SANDON PERFORMANCE TEE - T-shirt imprimé - navy
# ...                                                          ...
# NI114D0E9-Q11        AIR MAX 270  - Baskets basses - black/white
# AD116F00B-K11  U_PATH RUN SPORTS INSPIRED SHOES UNISEX - Bask...
# JOC43D00D-Q11                BRAND TEE - T-shirt imprimé - black
# AD116D03W-A11  GAZELLE  - Baskets basses - collegiate navy/fo...
# GE114D08Y-K11     ALONISSO BOY - Baskets montantes - navy/orange
#
#                                                            sizes  \
# sku
# NI114D0CS-Q12  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
# C1853E00F-Q11                                           [70, 80]
# LE224A08D-Q11                           [5a, 10a, 12a, 14a, 16a]
# LE226G005-A11       [2a, 3a, 4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# EL943D006-K11                     [8-9a, 10-11a, 12-13a, 13-14a]
# ...                                                          ...
# NI114D0E9-Q11   [28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5, 34, 35]
# AD116F00B-K11                   [28, 29, 30, 31, 32, 33, 34, 35]
# JOC43D00D-Q11                    [8-10a, 10-12a, 12-13a, 13-15a]
# AD116D03W-A11             [35.5, 36, 38, 36 2/3, 37 1/3, 38 2/3]
# GE114D08Y-K11                       [25, 28, 29, 30, 31, 37, 38]
#
#                                                          url_key  \
# sku
# NI114D0CS-Q12  nike-sportswear-court-borough-baskets-basses-n...
# C1853E00F-Q11  calvin-klein-jeans-logo-belt-ceinture-black-c1...
# LE224A08D-Q11      levisr-512-slim-taper-jean-slim-le224a08d-q11
# LE226G005-A11         levisr-t-shirt-imprime-white-le226g005-a11
# EL943D006-K11  ellesse-sandon-performance-tee-t-shirt-imprime...
# ...                                                          ...
# NI114D0E9-Q11  nike-sportswear-air-max-270-baskets-basses-bla...
# AD116F00B-K11  adidas-originals-u_path-run-sports-inspired-sh...
# JOC43D00D-Q11     jordan-brand-tee-t-shirt-imprime-joc43d00d-q11
# AD116D03W-A11  adidas-originals-gazelle-baskets-basses-ad116d...
# GE114D08Y-K11  geox-alonisso-boy-baskets-montantes-navyorange...
#
#                                                            media  \
# sku
# NI114D0CS-Q12  [{'path': 'spp-media-p1/5d261560a1373fc0ae8911...
# C1853E00F-Q11  [{'path': 'spp-media-p1/25b08a59481536469d7391...
# LE224A08D-Q11  [{'path': 'spp-media-p1/6d4d2e7e747e34d5a9b4b8...
# LE226G005-A11  [{'path': 'spp-media-p1/8d33b25d4a1b3a718e588e...
# EL943D006-K11  [{'path': 'spp-media-p1/ad9c9baa0a733962a92918...
# ...                                                          ...
# NI114D0E9-Q11  [{'path': 'spp-media-p1/5afe1683aa56320a90122f...
# AD116F00B-K11  [{'path': 'spp-media-p1/d76c88a7d8583d33828919...
# JOC43D00D-Q11  [{'path': 'spp-media-p1/40cde135de4d38a984488d...
# AD116D03W-A11  [{'path': 'spp-media-p1/570e4a36675f3fa4ac9f9d...
# GE114D08Y-K11  [{'path': 'spp-media-p1/dcd5599866b83ead8dc9b6...
#
#                        brand_name  is_premium family_articles  \
# sku
# NI114D0CS-Q12     Nike Sportswear       False              []
# C1853E00F-Q11  Calvin Klein Jeans       False              []
# LE224A08D-Q11             Levi's®       False              []
# LE226G005-A11             Levi's®       False              []
# EL943D006-K11             Ellesse       False              []
# ...                           ...         ...             ...
# NI114D0E9-Q11     Nike Sportswear       False              []
# AD116F00B-K11    adidas Originals       False              []
# JOC43D00D-Q11              Jordan       False              []
# AD116D03W-A11    adidas Originals       False              []
# GE114D08Y-K11                Geox       False              []
#
#                                                            flags  \
# sku
# NI114D0CS-Q12  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# C1853E00F-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# LE224A08D-Q11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# LE226G005-A11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# EL943D006-K11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# ...                                                          ...
# NI114D0E9-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# AD116F00B-K11  [{'key': 'discountRate', 'value': 'Jusqu’à -45...
# JOC43D00D-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# AD116D03W-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# GE114D08Y-K11  [{'key': 'discountRate', 'value': '-10%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# NI114D0CS-Q12          shoe                []        32,95 €
# C1853E00F-Q11   accessoires                []        24,95 €
# LE224A08D-Q11      clothing                []        34,95 €
# LE226G005-A11      clothing                []        17,95 €
# EL943D006-K11      clothing                []        17,95 €
# ...                     ...               ...            ...
# NI114D0E9-Q11          shoe                []        94,95 €
# AD116F00B-K11          shoe                []        49,95 €
# JOC43D00D-Q11      clothing                []        24,95 €
# AD116D03W-A11          shoe                []        59,95 €
# GE114D08Y-K11          shoe                []        54,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# NI114D0CS-Q12           24,65 €                        True
# C1853E00F-Q11           17,55 €                       False
# LE224A08D-Q11           26,15 €                        True
# LE226G005-A11           12,55 €                        True
# EL943D006-K11            9,95 €                       False
# ...                         ...                         ...
# NI114D0E9-Q11           80,45 €                       False
# AD116F00B-K11           27,45 €                        True
# JOC43D00D-Q11           21,15 €                       False
# AD116D03W-A11           41,95 €                        True
# GE114D08Y-K11           49,45 €                       False
#
#                price.has_different_original_prices  \
# sku
# NI114D0CS-Q12                                False
# C1853E00F-Q11                                False
# LE224A08D-Q11                                False
# LE226G005-A11                                False
# EL943D006-K11                                False
# ...                                            ...
# NI114D0E9-Q11                                False
# AD116F00B-K11                                False
# JOC43D00D-Q11                                False
# AD116D03W-A11                                False
# GE114D08Y-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# NI114D0CS-Q12                                    True
# C1853E00F-Q11                                   False
# LE224A08D-Q11                                    True
# LE226G005-A11                                    True
# EL943D006-K11                                   False
# ...                                               ...
# NI114D0E9-Q11                                   False
# AD116F00B-K11                                    True
# JOC43D00D-Q11                                   False
# AD116D03W-A11                                    True
# GE114D08Y-K11                                   False
#
#                price.has_discount_on_selected_sizes_only amount
# sku
# NI114D0CS-Q12                                      False    NaN
# C1853E00F-Q11                                      False    NaN
# LE224A08D-Q11                                      False    NaN
# LE226G005-A11                                      False    NaN
# EL943D006-K11                                      False    NaN
# ...                                                  ...    ...
# NI114D0E9-Q11                                      False    NaN
# AD116F00B-K11                                      False    NaN
# JOC43D00D-Q11                                      False    NaN
# AD116D03W-A11                                      False    NaN
# GE114D08Y-K11                                      False    NaN
#
# [336 rows x 17 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts()
# Out:
# Nike Sportswear     38
# adidas Originals    34
# Levi's®             28
# Name it             19
# Nike Performance    17
#                     ..
# Lemon Beret          1
# Gioseppo             1
# Froddo               1
# Skechers             1
# Kappa                1
# Name: brand_name, Length: 66, dtype: int64

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Nike Sportswear'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'adidas Originals'

# %%
df1
# Out:
#                                                             name  \
# sku
# NI114D0CS-Q12            COURT BOROUGH  - Baskets basses - black
# C1853E00F-Q11                LOGO BELT UNISEX - Ceinture - black
# LE224A08D-Q11       LVB 512 SLIM TAPER JEANS - Jean slim - hydra
# LE226G005-A11              BATWING TEE - T-shirt imprimé - white
# EL943D006-K11    SANDON PERFORMANCE TEE - T-shirt imprimé - navy
# ...                                                          ...
# NI114D0E9-Q11        AIR MAX 270  - Baskets basses - black/white
# AD116F00B-K11  U_PATH RUN SPORTS INSPIRED SHOES UNISEX - Bask...
# JOC43D00D-Q11                BRAND TEE - T-shirt imprimé - black
# AD116D03W-A11  GAZELLE  - Baskets basses - collegiate navy/fo...
# GE114D08Y-K11     ALONISSO BOY - Baskets montantes - navy/orange
#
#                                                            sizes  \
# sku
# NI114D0CS-Q12  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
# C1853E00F-Q11                                           [70, 80]
# LE224A08D-Q11                           [5a, 10a, 12a, 14a, 16a]
# LE226G005-A11       [2a, 3a, 4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# EL943D006-K11                     [8-9a, 10-11a, 12-13a, 13-14a]
# ...                                                          ...
# NI114D0E9-Q11   [28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5, 34, 35]
# AD116F00B-K11                   [28, 29, 30, 31, 32, 33, 34, 35]
# JOC43D00D-Q11                    [8-10a, 10-12a, 12-13a, 13-15a]
# AD116D03W-A11             [35.5, 36, 38, 36 2/3, 37 1/3, 38 2/3]
# GE114D08Y-K11                       [25, 28, 29, 30, 31, 37, 38]
#
#                                                          url_key  \
# sku
# NI114D0CS-Q12  nike-sportswear-court-borough-baskets-basses-n...
# C1853E00F-Q11  calvin-klein-jeans-logo-belt-ceinture-black-c1...
# LE224A08D-Q11      levisr-512-slim-taper-jean-slim-le224a08d-q11
# LE226G005-A11         levisr-t-shirt-imprime-white-le226g005-a11
# EL943D006-K11  ellesse-sandon-performance-tee-t-shirt-imprime...
# ...                                                          ...
# NI114D0E9-Q11  nike-sportswear-air-max-270-baskets-basses-bla...
# AD116F00B-K11  adidas-originals-u_path-run-sports-inspired-sh...
# JOC43D00D-Q11     jordan-brand-tee-t-shirt-imprime-joc43d00d-q11
# AD116D03W-A11  adidas-originals-gazelle-baskets-basses-ad116d...
# GE114D08Y-K11  geox-alonisso-boy-baskets-montantes-navyorange...
#
#                                                            media  \
# sku
# NI114D0CS-Q12  [{'path': 'spp-media-p1/5d261560a1373fc0ae8911...
# C1853E00F-Q11  [{'path': 'spp-media-p1/25b08a59481536469d7391...
# LE224A08D-Q11  [{'path': 'spp-media-p1/6d4d2e7e747e34d5a9b4b8...
# LE226G005-A11  [{'path': 'spp-media-p1/8d33b25d4a1b3a718e588e...
# EL943D006-K11  [{'path': 'spp-media-p1/ad9c9baa0a733962a92918...
# ...                                                          ...
# NI114D0E9-Q11  [{'path': 'spp-media-p1/5afe1683aa56320a90122f...
# AD116F00B-K11  [{'path': 'spp-media-p1/d76c88a7d8583d33828919...
# JOC43D00D-Q11  [{'path': 'spp-media-p1/40cde135de4d38a984488d...
# AD116D03W-A11  [{'path': 'spp-media-p1/570e4a36675f3fa4ac9f9d...
# GE114D08Y-K11  [{'path': 'spp-media-p1/dcd5599866b83ead8dc9b6...
#
#                        brand_name  is_premium family_articles  \
# sku
# NI114D0CS-Q12     Nike Sportswear       False              []
# C1853E00F-Q11  Calvin Klein Jeans       False              []
# LE224A08D-Q11             Levi's®       False              []
# LE226G005-A11             Levi's®       False              []
# EL943D006-K11             Ellesse       False              []
# ...                           ...         ...             ...
# NI114D0E9-Q11     Nike Sportswear       False              []
# AD116F00B-K11    adidas Originals       False              []
# JOC43D00D-Q11              Jordan       False              []
# AD116D03W-A11    adidas Originals       False              []
# GE114D08Y-K11                Geox       False              []
#
#                                                            flags  \
# sku
# NI114D0CS-Q12  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# C1853E00F-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# LE224A08D-Q11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# LE226G005-A11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# EL943D006-K11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# ...                                                          ...
# NI114D0E9-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# AD116F00B-K11  [{'key': 'discountRate', 'value': 'Jusqu’à -45...
# JOC43D00D-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# AD116D03W-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# GE114D08Y-K11  [{'key': 'discountRate', 'value': '-10%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# NI114D0CS-Q12          shoe                []          32.95
# C1853E00F-Q11   accessoires                []          24.95
# LE224A08D-Q11      clothing                []          34.95
# LE226G005-A11      clothing                []          17.95
# EL943D006-K11      clothing                []          17.95
# ...                     ...               ...            ...
# NI114D0E9-Q11          shoe                []          94.95
# AD116F00B-K11          shoe                []          49.95
# JOC43D00D-Q11      clothing                []          24.95
# AD116D03W-A11          shoe                []          59.95
# GE114D08Y-K11          shoe                []          54.95
#
#               price.promotional  price.has_different_prices  \
# sku
# NI114D0CS-Q12             24.65                        True
# C1853E00F-Q11             17.55                       False
# LE224A08D-Q11             26.15                        True
# LE226G005-A11             12.55                        True
# EL943D006-K11              9.95                       False
# ...                         ...                         ...
# NI114D0E9-Q11             80.45                       False
# AD116F00B-K11             27.45                        True
# JOC43D00D-Q11             21.15                       False
# AD116D03W-A11             41.95                        True
# GE114D08Y-K11             49.45                       False
#
#                price.has_different_original_prices  \
# sku
# NI114D0CS-Q12                                False
# C1853E00F-Q11                                False
# LE224A08D-Q11                                False
# LE226G005-A11                                False
# EL943D006-K11                                False
# ...                                            ...
# NI114D0E9-Q11                                False
# AD116F00B-K11                                False
# JOC43D00D-Q11                                False
# AD116D03W-A11                                False
# GE114D08Y-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# NI114D0CS-Q12                                    True
# C1853E00F-Q11                                   False
# LE224A08D-Q11                                    True
# LE226G005-A11                                    True
# EL943D006-K11                                   False
# ...                                               ...
# NI114D0E9-Q11                                   False
# AD116F00B-K11                                    True
# JOC43D00D-Q11                                   False
# AD116D03W-A11                                    True
# GE114D08Y-K11                                   False
#
#                price.has_discount_on_selected_sizes_only amount  \
# sku
# NI114D0CS-Q12                                      False    NaN
# C1853E00F-Q11                                      False    NaN
# LE224A08D-Q11                                      False    NaN
# LE226G005-A11                                      False    NaN
# EL943D006-K11                                      False    NaN
# ...                                                  ...    ...
# NI114D0E9-Q11                                      False    NaN
# AD116F00B-K11                                      False    NaN
# JOC43D00D-Q11                                      False    NaN
# AD116D03W-A11                                      False    NaN
# GE114D08Y-K11                                      False    NaN
#
#                discount_amount
# sku
# NI114D0CS-Q12              8.3
# C1853E00F-Q11              7.4
# LE224A08D-Q11              8.8
# LE226G005-A11              5.4
# EL943D006-K11              8.0
# ...                        ...
# NI114D0E9-Q11             14.5
# AD116F00B-K11             22.5
# JOC43D00D-Q11              3.8
# AD116D03W-A11             18.0
# GE114D08Y-K11              5.5
#
# [336 rows x 18 columns]

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc.min()
# Out:
# 0.7999999999999998

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
